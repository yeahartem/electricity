# %%
from pyH2A.run_pyH2A import pyH2A

# %%
result_109 = pyH2A('examples/211109_example.md', '.')
# Out:
# Levelized cost of hydrogen (base case): 225.15652501997127 $/kg

# %%
result_511 = pyH2A('examples/210511_example.md', '.')
# Out:
# Levelized cost of hydrogen (base case): 185.13183678616176 $/kg

# %%
result_613 = pyH2A('examples/210613_example.md', '.')
# Out:
# Levelized cost of hydrogen (base case): 6.091344832407182 $/kg

# %%
from pyH2A.Discounted_Cash_Flow import Discounted_Cash_Flow
d= Discounted_Cash_Flow('examples/210613_example.md')
# Out:
# 'Financial Input Values > construction time' is being created by pyH2A.Discounted_Cash_Flow
# 'Hourly Irradiation > Latitude' is being created by pyH2A.Plugins.Hourly_Irradiation_Plugin
# 'Hourly Irradiation > Longitude' is being created by pyH2A.Plugins.Hourly_Irradiation_Plugin
# 'Hourly Irradiation > No Tracking (kW)' is being created by pyH2A.Plugins.Hourly_Irradiation_Plugin
# 'Hourly Irradiation > Horizontal Single Axis Tracking (kW)' is being created by pyH2A.Plugins.Hourly_Irradiation_Plugin
# 'Hourly Irradiation > Two Axis Tracking (kW)' is being created by pyH2A.Plugins.Hourly_Irradiation_Plugin
# 'Hourly Irradiation > Mean solar input no tracking (kWh/m2/day)' is being created by pyH2A.Plugins.Hourly_Irradiation_Plugin
# 'Hourly Irradiation > Mean solar input single axis tracking (kWh/m2/day)' is being created by pyH2A.Plugins.Hourly_Irradiation_Plugin
# ...

# %%
d.inp['Monte_Carlo_Analysis']
# Out:
# {'Samples': {'Value': 1000},
#  'Target Price Range ($)': {'Value': '1.5; 2.5'},
#  'Input File': {'Value': 'pyH2A.Example~PV_E_Monte_Carlo.csv'}}
